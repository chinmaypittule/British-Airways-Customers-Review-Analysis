# %%
#imports

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

#regex
import re

# %%
cwd = os.getcwd()

df = pd.read_csv(cwd+"/BA_reviews.csv", index_col=0)

# %%
df.head()
# Out:
#                                              reviews  stars  \
# 0  ✅ Trip Verified |  The plane was extremely dir...    5.0
# 1  Not Verified | Overall journey wasn’t bad howe...    1.0
# 2  ✅ Trip Verified |  Overall very satisfied. Gro...    4.0
# 3  ✅ Trip Verified |  As always when I fly BA it ...    9.0
# 4  ✅ Trip Verified |  First time using BA busines...    1.0
#
#                 date         country
# 0  15th January 2024         Ireland
# 1  12th January 2024  United Kingdom
# 2  12th January 2024  United Kingdom
# 3   9th January 2024           Spain
# 4   7th January 2024  United Kingdom

# %%
df.tail()
# Out:
#                                                 reviews  stars  \
# 3729  YYZ to LHR - July 2012 - I flew overnight in p...    8.0
# 3730  LHR to HAM. Purser addresses all club passenge...    2.0
# 3731  My son who had worked for British Airways urge...    7.0
# 3732  London City-New York JFK via Shannon on A318 b...    1.0
# 3733  SIN-LHR BA12 B747-436 First Class. Old aircraf...   10.0
#
#                    date         country
# 3729   29th August 2012          Canada
# 3730   28th August 2012  United Kingdom
# 3731  12th October 2011  United Kingdom
# 3732  11th October 2011   United States
# 3733   9th October 2011  United Kingdom

# %%
df['IsVerified'] = df.reviews.str.contains("Trip Verified")

# %%
df
# Out:
#                                                 reviews  stars  \
# 0     ✅ Trip Verified |  The plane was extremely dir...    5.0
# 1     Not Verified | Overall journey wasn’t bad howe...    1.0
# 2     ✅ Trip Verified |  Overall very satisfied. Gro...    4.0
# 3     ✅ Trip Verified |  As always when I fly BA it ...    9.0
# 4     ✅ Trip Verified |  First time using BA busines...    1.0
# ...                                                 ...    ...
# 3729  YYZ to LHR - July 2012 - I flew overnight in p...    8.0
# 3730  LHR to HAM. Purser addresses all club passenge...    2.0
# 3731  My son who had worked for British Airways urge...    7.0
# 3732  London City-New York JFK via Shannon on A318 b...    1.0
# 3733  SIN-LHR BA12 B747-436 First Class. Old aircraf...   10.0
#
#                    date         country  IsVerified
# 0     15th January 2024         Ireland        True
# 1     12th January 2024  United Kingdom       False
# 2     12th January 2024  United Kingdom        True
# 3      9th January 2024           Spain        True
# 4      7th January 2024  United Kingdom        True
# ...                 ...             ...         ...
# 3729   29th August 2012          Canada       False
# 3730   28th August 2012  United Kingdom       False
# 3731  12th October 2011  United Kingdom       False
# 3732  11th October 2011   United States       False
# 3733   9th October 2011  United Kingdom       False
#
# [3734 rows x 5 columns]

# %% [markdown]
# ### Removing prefix

# %%
prefixes_to_remove = ["✅ Trip Verified |", "Not Verified |"]

reviews_data = df.reviews.copy()

for prefix in prefixes_to_remove:
    reviews_data = reviews_data.str.replace(prefix, "")
    df.reviews = reviews_data

# %%
df.head()
# Out:
#                                              reviews  stars  \
# 0    The plane was extremely dirty with chocolate...    5.0
# 1   Overall journey wasn’t bad however at the end...    1.0
# 2    Overall very satisfied. Ground staff member ...    4.0
# 3    As always when I fly BA it was a total shamb...    9.0
# 4    First time using BA business class but we we...    1.0
#
#                 date         country  IsVerified
# 0  15th January 2024         Ireland        True
# 1  12th January 2024  United Kingdom       False
# 2  12th January 2024  United Kingdom        True
# 3   9th January 2024           Spain        True
# 4   7th January 2024  United Kingdom        True

# %%
df
# Out:
#                                                 reviews  stars  \
# 0       The plane was extremely dirty with chocolate...    5.0
# 1      Overall journey wasn’t bad however at the end...    1.0
# 2       Overall very satisfied. Ground staff member ...    4.0
# 3       As always when I fly BA it was a total shamb...    9.0
# 4       First time using BA business class but we we...    1.0
# ...                                                 ...    ...
# 3729  YYZ to LHR - July 2012 - I flew overnight in p...    8.0
# 3730  LHR to HAM. Purser addresses all club passenge...    2.0
# 3731  My son who had worked for British Airways urge...    7.0
# 3732  London City-New York JFK via Shannon on A318 b...    1.0
# 3733  SIN-LHR BA12 B747-436 First Class. Old aircraf...   10.0
#
#                    date         country  IsVerified
# 0     15th January 2024         Ireland        True
# 1     12th January 2024  United Kingdom       False
# 2     12th January 2024  United Kingdom        True
# 3      9th January 2024           Spain        True
# 4      7th January 2024  United Kingdom        True
# ...                 ...             ...         ...
# 3729   29th August 2012          Canada       False
# 3730   28th August 2012  United Kingdom       False
# 3731  12th October 2011  United Kingdom       False
# 3732  11th October 2011   United States       False
# 3733   9th October 2011  United Kingdom       False
#
# [3734 rows x 5 columns]

# %%
df.dtypes
# Out:
# reviews        object
# stars         float64
# date           object
# country        object
# IsVerified       bool
# dtype: object

# %% [markdown]
# ### Converting Date to Datetime format

# %%
from dateutil import parser

df['date'] = df['date'].apply(lambda x: parser.parse(x))

# %%
df.date
# Out:
# 0      2024-01-15
# 1      2024-01-12
# 2      2024-01-12
# 3      2024-01-09
# 4      2024-01-07
#           ...
# 3729   2012-08-29
# 3730   2012-08-28
# 3731   2011-10-12
# 3732   2011-10-11
# 3733   2011-10-09
# Name: date, Length: 3734, dtype: datetime64[ns]

# %%
df.isnull().value_counts()
# Out:
# reviews  stars  date   country  IsVerified
# False    False  False  False    False         3727
#          True   False  False    False            5
#          False  False  True     False            2
# Name: count, dtype: int64

# %%
df.country.isnull().sum()
# Out:
# 2

# %%
df.stars.isnull().sum()
# Out:
# 5

# %%
df[df.stars.isnull()]
# Out:
#                                                 reviews  stars       date  \
# 3186  Travelled Business A380 LHR-HK and returned on...    NaN 2015-01-26
# 3321  First time with BA (a code share flight for JA...    NaN 2014-11-20
# 3340  BA 83 from LHR to LAX first time on Airbus A38...    NaN 2014-11-12
# 3579  BA026 7th July Seat 66B. Arrived HK off a conn...    NaN 2014-07-08
# 3606  Flew from LHR to Hong Kong April 13th 2014 BA ...    NaN 2014-06-25
#
#              country  IsVerified
# 3186  United Kingdom       False
# 3321       Australia       False
# 3340   United States       False
# 3579  United Kingdom       False
# 3606  United Kingdom       False

# %% [markdown]
# ### Removing rows with Null values

# %%
df.drop(df[(df.country.isnull() == True)].index, axis=0, inplace=True)

# %%
df.drop(df[(df.stars.isnull() == True)].index, axis=0, inplace=True)

# %%
df.isnull().value_counts()
# Out:
# reviews  stars  date   country  IsVerified
# False    False  False  False    False         3727
# Name: count, dtype: int64

# %%
df
# Out:
#                                                 reviews  stars       date  \
# 0       The plane was extremely dirty with chocolate...    5.0 2024-01-15
# 1      Overall journey wasn’t bad however at the end...    1.0 2024-01-12
# 2       Overall very satisfied. Ground staff member ...    4.0 2024-01-12
# 3       As always when I fly BA it was a total shamb...    9.0 2024-01-09
# 4       First time using BA business class but we we...    1.0 2024-01-07
# ...                                                 ...    ...        ...
# 3729  YYZ to LHR - July 2012 - I flew overnight in p...    8.0 2012-08-29
# 3730  LHR to HAM. Purser addresses all club passenge...    2.0 2012-08-28
# 3731  My son who had worked for British Airways urge...    7.0 2011-10-12
# 3732  London City-New York JFK via Shannon on A318 b...    1.0 2011-10-11
# 3733  SIN-LHR BA12 B747-436 First Class. Old aircraf...   10.0 2011-10-09
#
#              country  IsVerified
# 0            Ireland        True
# 1     United Kingdom       False
# 2     United Kingdom        True
# 3              Spain        True
# 4     United Kingdom        True
# ...              ...         ...
# 3729          Canada       False
# 3730  United Kingdom       False
# 3731  United Kingdom       False
# 3732   United States       False
# 3733  United Kingdom       False
#
# [3727 rows x 5 columns]

# %% [markdown]
# ### Removing special characters

# %%
import re

# Define a function to clean the text
def clean(text):
# Removes all special characters and numericals leaving the alphabets
    text = re.sub('[^A-Za-z]+', ' ', str(text))
    return text

# Cleaning the text in the review column
df['Cleaned Reviews'] = df['reviews'].apply(clean)
df.head()
# Out:
#                                              reviews  stars       date  \
# 0    The plane was extremely dirty with chocolate...    5.0 2024-01-15
# 1   Overall journey wasn’t bad however at the end...    1.0 2024-01-12
# 2    Overall very satisfied. Ground staff member ...    4.0 2024-01-12
# 3    As always when I fly BA it was a total shamb...    9.0 2024-01-09
# 4    First time using BA business class but we we...    1.0 2024-01-07
#
#           country  IsVerified  \
# 0         Ireland        True
# 1  United Kingdom       False
# 2  United Kingdom        True
# 3           Spain        True
# 4  United Kingdom        True
#
#                                      Cleaned Reviews
# 0   The plane was extremely dirty with chocolate ...
# 1   Overall journey wasn t bad however at the end...
# 2   Overall very satisfied Ground staff member at...
# 3   As always when I fly BA it was a total shambl...
# 4   First time using BA business class but we wer...

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk import pos_tag
nltk.download('stopwords')
from nltk.corpus import stopwords
nltk.download('wordnet')
from nltk.corpus import wordnet
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### Removing stopwords

# %%
def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(text)
    filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
    return ' '.join(filtered_tokens)

df['withoutstopwords'] = df['Cleaned Reviews'].apply(remove_stopwords)

# %%
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

def lemmatize_text(text):
    lemmatizer = WordNetLemmatizer()
    tokens = word_tokenize(text)
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return ' '.join(lemmatized_tokens)
    
df['lemmatized_column'] = df['withoutstopwords'].apply(lemmatize_text)

# %%
def stem(word):
    for suffix in ['ing', 'ly', 'ed', 'ious', 'ies', 'ive', 'es', 's', 'ment']:
        if word.endswith(suffix):
            return re.findall(r'^(.*)(ing|ly|ed|ious|ies|ive|es|s|ment)$', word)[0][0]
    return word

def stemmer(phrase):
    stemmed_phrase = [stem(word) for word in phrase]
    return stemmed_phrase

# Apply stemmer to DataFrame column
df['stemmed_text'] = df['lemmatized_column'].apply(lambda x: stemmer(x.split()))
df['stemmed_sentence'] = df['stemmed_text'].apply(lambda x: ' '.join(x))

# %%
df.head()
# Out:
#                                              reviews  stars       date  \
# 0    The plane was extremely dirty with chocolate...    5.0 2024-01-15
# 1   Overall journey wasn’t bad however at the end...    1.0 2024-01-12
# 2    Overall very satisfied. Ground staff member ...    4.0 2024-01-12
# 3    As always when I fly BA it was a total shamb...    9.0 2024-01-09
# 4    First time using BA business class but we we...    1.0 2024-01-07
#
#           country  IsVerified  \
# 0         Ireland        True
# 1  United Kingdom       False
# 2  United Kingdom        True
# 3           Spain        True
# 4  United Kingdom        True
#
#                                      Cleaned Reviews  \
# 0   The plane was extremely dirty with chocolate ...
# 1   Overall journey wasn t bad however at the end...
# 2   Overall very satisfied Ground staff member at...
# 3   As always when I fly BA it was a total shambl...
# 4   First time using BA business class but we wer...
#
#                                     withoutstopwords  \
# 0  plane extremely dirty chocolate smudged mine c...
# 1  Overall journey bad however end baggage arriva...
# 2  Overall satisfied Ground staff member YVR extr...
# 3  always fly BA total shambles booked Manchester...
# 4  First time using BA business class pleased ser...
#
#                                    lemmatized_column  \
# 0  plane extremely dirty chocolate smudged mine c...
# 1  Overall journey bad however end baggage arriva...
# 2  Overall satisfied Ground staff member YVR extr...
# 3  always fly BA total shamble booked Manchester ...
# 4  First time using BA business class pleased ser...
#
#                                         stemmed_text  \
# 0  [plane, extreme, dirty, chocolate, smudg, mine...
# 1  [Overall, journey, bad, however, end, baggage,...
# 2  [Overall, satisfi, Ground, staff, member, YVR,...
# 3  [alway, f, BA, total, shamble, book, Mancheste...
# 4  [First, time, us, BA, busines, clas, pleas, se...
#
#                                     stemmed_sentence
# 0  plane extreme dirty chocolate smudg mine child...
# 1  Overall journey bad however end baggage arriva...
# 2  Overall satisfi Ground staff member YVR extrem...
# 3  alway f BA total shamble book Manchester Londo...
# 4  First time us BA busines clas pleas service re...

# %%
df.to_csv(cwd + "/cleaned-BA-reviews.csv")
